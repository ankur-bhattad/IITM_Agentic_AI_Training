# %%
from langchain_openai import ChatOpenAI
import utils

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5
    )

# Simple query
response = llm.invoke("Explain quantum computing in simple terms max 50 words")
print(response.content)
# Out:
# Quantum computing uses quantum bits (qubits) to perform calculations at speeds far beyond traditional computers. Unlike regular bits, which are either 0 or 1, qubits can be both at the same time, enabling complex problem-solving and data processing through quantum mechanics principles.

# %% [markdown]
# # Building a Simple Chat Application

# %%
from langchain_core.prompts import ChatPromptTemplate

# %% [raw]
# # Prompt templates are essential for generating dynamic and flexible prompts that cater to various use cases, such as conversation history,
# # structured outputs, and specialized queries.

# %%
# Create a prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI tutor. Respond to student questions clearly and shortest way possible."),
    ("human", "{input}")
])

# %%
# Set up the chain
chain = prompt | llm

# Interactive chat
print("AI Tutor: Hello! Ask me anything. Type 'quit' to exit.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'quit':
        break
    response = chain.invoke({"input": user_input})
    print(f"AI Tutor: {response.content}")
# Out:
# AI Tutor: Hello! Ask me anything. Type 'quit' to exit.
# AI Tutor: Quantum computing is a type of computing that uses the principles of quantum mechanics to process information. Unlike classical computers that use bits (0s and 1s), quantum computers use quantum bits, or qubits.
#
# A qubit can exist in multiple states simultaneously due to superposition, meaning it can be both 0 and 1 at the same time. Additionally, qubits can be entangled, allowing them to be interconnected in ways that classical bits cannot. This enables quantum computers to perform complex calculations much more efficiently than classical computers for certain tasks.

# %% [markdown]
# # Building a Task Planner

# %%
# Task-planner agent using langchain
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert task planner. Break down complex tasks into manageable steps."),
    ("human", "{task_description}")
])
chain = prompt | llm
task_description = "Plan a week-long trip to Japan focusing on cultural experiences."
response = chain.invoke({"task_description": task_description})
print(response.content)
