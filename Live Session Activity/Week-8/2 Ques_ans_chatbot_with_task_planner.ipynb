# %%
from langchain_openai import ChatOpenAI
import utils

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.5
    )

# Simple query
response = llm.invoke("Explain quantum computing in simple terms max 50 words")
print(response.content)
# Out:
# Quantum computing uses the principles of quantum mechanics to process information. Unlike classical computers that use bits (0s and 1s), quantum computers use qubits, which can be both 0 and 1 simultaneously. This allows them to solve complex problems much faster than traditional computers.

# %% [markdown]
# # Building a Simple Chat Application

# %%
from langchain_core.prompts import ChatPromptTemplate

# %% [raw]
# # Prompt templates are essential for generating dynamic and flexible prompts that cater to various use cases, such as conversation history,
# # structured outputs, and specialized queries.

# %%
# Create a prompt template
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful AI tutor. Respond to student questions clearly and shortest way possible."),
    ("human", "{input}")
])

# %%
# Set up the chain
chain = prompt | llm

# Interactive chat
print("AI Tutor: Hello! Ask me anything. Type 'quit' to exit.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'quit':
        break
    response = chain.invoke({"input": user_input})
    print(f"AI Tutor: {response.content}")
# Out:
# AI Tutor: Hello! Ask me anything. Type 'quit' to exit.

# %% [markdown]
# # Building a Task Planner

# %%
# Task-planner agent using langchain
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are an expert task planner. Break down complex tasks into manageable steps."),
    ("human", "{task_description}")
])
chain = prompt | llm
task_description = "Plan a week-long trip to Japan focusing on cultural experiences."
response = chain.invoke({"task_description": task_description})
print(response.content)
# Out:
# Planning a week-long trip to Japan with a focus on cultural experiences can be an exciting adventure. Here’s a detailed breakdown of the trip, including daily activities, locations, and cultural highlights.
#
# ### **Trip Overview:**
# - **Duration:** 7 Days
# - **Focus:** Cultural Experiences
# - **Main Locations:** Tokyo, Kyoto, Nara, and Osaka
#
# ### **Day 1: Arrival in Tokyo**
# 1. **Morning:**
#    - Arrive at Narita or Haneda Airport.
#    - Transfer to hotel in Tokyo (Shinjuku or Shibuya recommended).
#    - Check-in and freshen up.
#
# 2. **Afternoon:**
#    - Visit the **Meiji Shrine**, an important Shinto shrine surrounded by a beautiful forest.
#    - Explore **Harajuku** for youth culture and unique fashion.
#
# 3. **Evening:**
#    - Dinner at a traditional Izakaya (Japanese pub) in Shinjuku.
#    - Stroll through **Shinjuku Gyoen National Garden** for a peaceful evening.
#
# ### **Day 2: Tokyo Cultural Exploration**
# 1. **Morning:**
#    - Visit **Asakusa** and explore **Senso-ji Temple**, Tokyo's oldest temple.
#    - Try traditional snacks from the Nakamise shopping street.
#
# 2. **Afternoon:**
#    - Participate in a **Tea Ceremony** experience in a local tea house.
#    - Visit the **Ueno Park** and its museums (Tokyo National Museum for art and history).
#
# 3. **Evening:**
#    - Explore **Akihabara** for a taste of otaku culture.
#    - Dinner at a themed restaurant (e.g., Robot Restaurant or Maid Café).
#
# ### **Day 3: Day Trip to Nara**
# 1. **Morning:**
#    - Take a train to **Nara** (about 1 hour).
#    - Visit **Todai-ji Temple**, home to a giant Buddha statue.
#
# 2. **Afternoon:**
#    - Explore **Nara Park**, famous for its free-roaming deer.
#    - Visit **Kasuga-taisha Shrine** known for its lanterns.
#
# 3. **Evening:**
#    - Return to Tokyo.
#    - Dinner at a local ramen shop.
#
# ### **Day 4: Travel to Kyoto**
# 1. **Morning:**
#    - Take the Shinkansen (bullet train) to **Kyoto** (about 2.5 hours).
#    - Check into a traditional ryokan (Japanese inn).
#
# 2. **Afternoon:**
#    - Visit **Kinkaku-ji (Golden Pavilion)**, a stunning Zen temple.
#    - Explore the **Ryoan-ji** rock garden.
#
# 3. **Evening:**
#    - Dinner at a kaiseki restaurant for a multi-course traditional meal.
#    - Evening walk in the **Gion district**, possibly spot a Geisha.
#
# ### **Day 5: Kyoto Cultural Immersion**
# 1. **Morning:**
#    - Participate in a **Kimono-wearing experience**.
#    - Visit **Fushimi Inari Taisha**, famous for its thousands of red torii gates.
#
# 2. **Afternoon:**
#    - Explore **Arashiyama**: visit the **Bamboo Grove** and **Iwatayama Monkey Park**.
#    - Enjoy a boat ride on the Hozu River (if time permits).
#
# 3. **Evening:**
#    - Dinner at a local izakaya.
#    - Attend a **traditional Japanese performance** (e.g., Kyo-Mai dance).
#
# ### **Day 6: Day Trip to Osaka**
# 1. **Morning:**
#    - Take a train to **Osaka** (about 30 minutes).
#    - Visit **Osaka Castle** and its surrounding park.
#
# 2. **Afternoon:**
#    - Explore **Dotonbori**, famous for street food (try takoyaki and okonomiyaki).
#    - Visit the **Osaka Museum of History**.
#
# 3. **Evening:**
#    - Return to Kyoto.
#    - Enjoy a relaxing evening at the ryokan, possibly with an onsen experience.
#
# ### **Day 7: Departure**
# 1. **Morning:**
#    - Last-minute shopping in Kyoto (Nishiki Market for souvenirs).
#    - Check out of the ryokan.
#
# 2. **Afternoon:**
#    - Travel back to Tokyo via Shinkansen.
#    - Depending on flight time, visit any missed attractions or relax in a café.
#
# 3. **Evening:**
#    - Depart from Narita or Haneda Airport.
#
# ### **Tips for Cultural Experiences:**
# - **Language:** Learn a few basic Japanese phrases to enhance interactions.
# - **Etiquette:** Familiarize yourself with Japanese customs (bowing, removing shoes indoors).
# - **Cash:** Carry cash, as many traditional places may not accept credit cards.
# - **Transportation:** Consider getting a Japan Rail Pass for unlimited travel on JR trains.
#
# By following this detailed plan, you can ensure a culturally rich and memorable experience during your week in Japan!
