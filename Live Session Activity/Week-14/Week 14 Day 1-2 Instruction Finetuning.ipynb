# %%
import langchain, langchain_community
print(langchain.__version__)
print(langchain_community.__version__)
# !pip install langchain==0.3.27 langchain-openai==0.3.33 langchain-community==0.3.24
# Out:
# 0.1.13
# 0.0.29

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import json
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from textwrap import indent
import utils

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
customer = {
    "name": "Sarah Johnson",
    "reason": "credit_score", 
    "product": "Personal Loan"
}

# %%
basic_prompt = f"Write email to {customer['name']}: loan rejected due to {customer['reason']}"

# %%
basic_prompt_response = llm.invoke(basic_prompt)
print(basic_prompt_response.content)
# Out:
# Subject: Loan Application Update
#
# Dear Sarah,
#
# I hope this message finds you well. I am writing to inform you about the status of your recent loan application.
#
# After careful review, we regret to inform you that your application has been rejected due to your current credit score. We understand that this news may be disappointing, and we want to assure you that this decision was made after thorough consideration of all factors involved.
#
# If you would like, we can provide you with more details regarding your credit report and discuss potential steps you can take to improve your credit score for future applications. Our team is here to support you and answer any questions you may have.
#
# Thank you for your understanding, and we appreciate your interest in our services.
#
# Best regards,
#
# [Your Name]
# [Your Position]
# [Your Company]
# [Your Contact Information]

# %%
Instruction_prompt = f"""
You are a FinTech customer officer. Write professional email to {customer['name']} about {customer['product']} rejection.

Guidelines:
- Start with appreciation
- State decision clearly but gently  
- Give general reason (no specific numbers)
- Offer next steps
- Use empathetic, compliant tone
- Professional closing
"""

# %%
print("\nInstruction Tuning RESPONSE:")

Instruction_prompt_response = llm.invoke(Instruction_prompt)
print(Instruction_prompt_response.content)
# Out:
# Instruction Tuning RESPONSE:
# Subject: Update on Your Personal Loan Application
#
# Dear Sarah,
#
# I hope this message finds you well. Thank you for considering us for your personal loan needs and for the time you invested in the application process. We truly appreciate your interest in our services.
#
# After careful review, I regret to inform you that we are unable to approve your personal loan application at this time. This decision was based on a variety of factors related to our lending criteria, which we must adhere to in order to ensure responsible lending practices.
#
# I understand that this news may be disappointing, and I want to assure you that we value your financial well-being. If you would like, I can provide you with some general feedback on your application and discuss potential steps you might take to improve your chances for future applications.
#
# Please feel free to reach out if you have any questions or if you would like to explore other options that may be available to you. We are here to help and support you in any way we can.
#
# Thank you once again for your understanding, and I wish you all the best in your financial journey.
#
# Warm regards,
#
# [Your Name]
# [Your Title]
# [Your Company]
# [Your Contact Information]

# %%
mock_customers = [

    {
        "name": "Priya Shah",
        "product_type": "Credit Card",
        "rejection_reason": "high existing credit utilization",
        "email": "priya.shah@example.com",
        "customer_since": "2019",
        "tier": "Standard",
        "location": "Pune, India"
    },

    {
        "name": "Rohit Khanna",
        "product_type": "Business Loan",
        "rejection_reason": "incomplete business documentation",
        "email": "rohit.khanna@example.com",
        "customer_since": "2020",
        "tier": "Enterprise",
        "location": "Bangalore, India"
    },

    {
        "name": "Neha Iyer",
        "product_type": "Home Loan",
        "rejection_reason": "unstable recent income pattern",
        "email": "neha.iyer@example.com",
        "customer_since": "2018",
        "tier": "Premium",
        "location": "Chennai, India"
    },

    {
        "name": "Sandeep Kulkarni",
        "product_type": "Auto Loan",
        "rejection_reason": "policy criteria not met",
        "email": "sandeep.k@example.com",
        "customer_since": "2022",
        "tier": "Standard",
        "location": "Hyderabad, India"
    }
]

# %%
instructions = f"""
You are a customer relationship officer at a FinTech company.
Write an empathetic, compliant, and professional email to {mock_customers[0]['name']} explaining why their {mock_customers[0]['product_type']} application was not approved.

CUSTOMER DETAILS:
- Customer Name: {mock_customers[0]['name']}
- Product Applied: {mock_customers[0]['product_type']}
- Primary Reason: {mock_customers[0]['rejection_reason']}

FOLLOW THESE STRICT GUIDELINES:

1. TONE & EMPATHY:
   - Begin with genuine appreciation for their application
   - Use empathetic language that acknowledges disappointment
   - Maintain professional yet warm tone throughout
   - Avoid robotic or cold corporate language

2. CLARITY & COMPLIANCE:
   - State the decision clearly in the first paragraph
   - Explain the general reason without technical jargon
   - Never mention specific credit scores, income amounts, or personal details
   - Use compliant language that cannot be interpreted as discriminatory
   - Focus on "policy requirements" rather than personal shortcomings

3. STRUCTURE & CONTENT:
   - Subject line: Clear but not alarming
   - Opening: Thank customer for their trust and application
   - Decision: State rejection clearly but gently
   - Reason: General, policy-based explanation
   - Next steps: Offer constructive path forward
   - Closing: Express hope for future relationship

4. BRAND ALIGNMENT:
   - Use company name: "FinTrust Capital"
   - Include standard compliance disclaimer
   - Offer customer service contact information
   - Maintain brand voice: professional yet approachable

5. FORMATTING:
   - Professional email format with appropriate spacing
   - Natural paragraph breaks for readability
   - Appropriate salutation and closing
   - Include placeholder for customer service details

Avoid any language that could be construed as:
- Discriminatory based on age, gender, ethnicity, etc.
- Making promises or guarantees about future approvals
- Sharing specific underwriting criteria or thresholds
"""

# %%
response = llm.invoke(instructions)
print(response.content)
# Out:
# Subject: Update on Your Credit Card Application
#
# Dear Priya Shah,
#
# Thank you for choosing FinTrust Capital and for trusting us with your credit card application. We truly appreciate the opportunity to serve you and understand how important this decision is for you.
#
# After careful consideration, we regret to inform you that your application for a credit card has not been approved at this time. This decision is based on our policy requirements, specifically related to existing credit utilization levels. We understand that this news may be disappointing, and we want to assure you that this decision is not a reflection of your personal financial situation but rather a result of our internal guidelines.
#
# We encourage you to review your current credit utilization and consider taking steps to improve it. This may enhance your chances for future applications. Additionally, we invite you to reach out to our customer service team, who can provide further insights and guidance on how to strengthen your credit profile.
#
# Thank you once again for your interest in FinTrust Capital. We value your relationship and hope to have the opportunity to assist you in the future.
#
# Warm regards,
#
# [Your Name]
# Customer Relationship Officer
# FinTrust Capital
# [Customer Service Contact Information]
#
# *Disclaimer: This email is for informational purposes only and does not constitute a credit decision. All applications are subject to our standard underwriting criteria.*

# %% [markdown]
# ## <b>Basic Prompting vs. Structured Instruction Prompting specifically for FinTech rejection-email + ticket summarizer scenarios.</b>
#
# | Dimension                         | **Basic Prompting (Raw Prompt)**                   | **Instruction-Based + Role Prompting**        | **Business Impact**                          |
# | --------------------------------- | -------------------------------------------------- | --------------------------------------------- | -------------------------------------------- |
# | **Output Consistency**            | Highly variable, unpredictable tone                | Stable, repeatable, policy-aligned            | Reduces compliance & brand-voice risk        |
# | **Regulatory Compliance**         | Often misses legal wording, may over-share details | Explicit rules prevent violations             | Prevents regulatory breaches & penalties     |
# | **Tone & Empathy**                | Robotic or overly casual                           | Warm, empathetic, human-like                  | Better customer trust & reduced complaints   |
# | **Actionability**                 | Missing steps or vague summaries                   | Clear conclusions, next steps, and structure  | Shorter resolution times, improved CSAT      |
# | **Error Rate**                    | High — model hallucination, missing key details    | Low — instructions constrain behavior         | Prevents misinformation & legal exposure     |
# | **Domain Alignment**              | Generic content, not industry-aware                | Deeply aligned to FinTech tone + workflow     | Boosts credibility & professionalism         |
# | **Scalability**                   | Inconsistent when scaled across agents             | Uniform responses across thousands of tickets | Operational efficiency & lower training cost |
# | **Auditability**                  | Hard to justify or trace decision logic            | Structured outputs → audit-ready              | Crucial for regulated FinTech workflows      |
# | **Customer Dissatisfaction Risk** | High — tone mistakes, unclear decisions            | Low — controlled, empathetic narrative        | Fewer escalations, higher NPS                |
