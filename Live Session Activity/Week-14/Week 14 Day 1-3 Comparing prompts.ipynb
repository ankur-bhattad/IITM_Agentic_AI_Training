# %%
import langchain, langchain_community
print(langchain.__version__)
print(langchain_community.__version__)
# !pip install langchain==0.3.27 langchain-openai==0.3.33 langchain-community==0.3.24
# Out:
# 0.1.13
# 0.0.29

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import json
from langchain_openai import ChatOpenAI
from langchain.schema import HumanMessage, SystemMessage
from textwrap import indent
import utils

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

# %%
def compare_prompts(raw_prompt: str, tuned_prompt: str, title="Comparison"):
    """
    Compare raw prompt vs tuned prompt using the same LLM.
    Prints clean side-by-side responses.
    """

    print(f"{title}")
    print("==============================\n")

    # RAW PROMPT CALL
    raw_messages = [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content=raw_prompt)
    ]
    raw_response = llm(raw_messages).content.strip()

    # TUNED PROMPT CALL
    tuned_messages = [
        SystemMessage(content="You are a helpful assistant."),
        HumanMessage(content=tuned_prompt)
    ]
    tuned_response = llm(tuned_messages).content.strip()

    # PRINT OUTPUTS
    print("RAW PROMPT:")
    print("--------------------------------")
    print(raw_prompt)
    print("\nRAW RESPONSE:")
    print(indent(raw_response, "    "))

    print("\n\nTUNED PROMPT:")
    print("--------------------------------")
    print(tuned_prompt)
    print("\nTUNED RESPONSE:")
    print(indent(tuned_response, "    "))

    print("\n==============================")
    print("END OF COMPARISON")

# %%
# EXAMPLE USAGE — FINTECH LOAN DECISION EXPLAINER

raw_prompt_loan = """
Explain why the customer was denied the loan.
"""

tuned_prompt_loan = """
You are a financial assistant that explains loan decisions clearly.

Rules:
• Do NOT invent reasons — only use provided ones.
• Do NOT mention internal scoring systems.
• Be supportive and simple.
• Provide next steps.

Input:
Loan Status: DENIED
Reason Provided: Low credit history, missing income documents.

Format:
1. Summary
2. Main Factors (bullets)
3. Next Steps
"""

compare_prompts(raw_prompt_loan, tuned_prompt_loan, title="FinTech Loan Decision Explainer")
# Out:
# FinTech Loan Decision Explainer
# ==============================
#
# RAW PROMPT:
# --------------------------------
#
# Explain why the customer was denied the loan.
#
#
# RAW RESPONSE:
#     To provide a specific explanation for why a customer was denied a loan, I would need more context about the situation, such as the customer's financial history, credit score, income level, debt-to-income ratio, or any other relevant factors considered by the lender. However, I can outline some common reasons why loan applications are typically denied:
#
#     1. **Low Credit Score**: A credit score below the lender's minimum requirement can lead to a denial. Lenders use credit scores to assess the risk of lending money.
#
#     2. **Insufficient Income**: If the applicant's income is not sufficient to cover the loan payments, the lender may deny the application. Lenders often look for a stable income that meets their debt-to-income ratio requirements.
#
#     3. **High Debt-to-Income Ratio**: If the applicant has too much existing debt compared to their income, it may indicate that they cannot handle additional debt, leading to a denial.
#
#     4. **Lack of Credit History**: A limited or nonexistent credit history can make it difficult for lenders to assess the applicant's creditworthiness.
#
#     5. **Employment History**: A lack of stable employment or frequent job changes can raise concerns for lenders about the applicant's ability to repay the loan.
#
#     6. **Incomplete Application**: If the loan application is missing required information or documentation, it may be denied.
#
#     7. **Negative Financial History**: Previous bankruptcies, foreclosures, or defaults can negatively impact the applicant's chances of loan approval.
#
#     8. **Collateral Issues**: For secured loans, if the collateral does not meet the lender's requirements or is deemed insufficient, the loan may be denied.
#
#     9. **Loan Purpose**: Some lenders have restrictions on the purpose of the loan, and if the intended use does not align with their policies, the application may be denied.
#
#     If you have specific details about the customer's situation, I can provide a more tailored explanation.
#
#
# TUNED PROMPT:
# --------------------------------
#
# You are a financial assistant that explains loan decisions clearly.
#
# Rules:
# • Do NOT invent reasons — only use provided ones.
# • Do NOT mention internal scoring systems.
# • Be supportive and simple.
# • Provide next steps.
#
# Input:
# Loan Status: DENIED
# Reason Provided: Low credit history, missing income documents.
#
# Format:
# 1. Summary
# 2. Main Factors (bullets)
# 3. Next Steps
#
#
# TUNED RESPONSE:
#     1. **Summary**
#     Your loan application has been denied. This decision is based on a couple of important factors related to your credit history and documentation.
#
#     2. **Main Factors**
#     - Low credit history: This indicates that there may not be enough information available to assess your creditworthiness.
#     - Missing income documents: Not providing the necessary income documentation can make it difficult to verify your ability to repay the loan.
#
#     3. **Next Steps**
#     - Consider improving your credit history by making timely payments on existing debts and avoiding new debt.
#     - Gather and submit the required income documents, such as pay stubs or tax returns, to strengthen your application.
#     - Once you have addressed these issues, you can reapply for the loan or explore other lending options. If you have questions or need assistance, feel free to reach out!
#
# ==============================
# END OF COMPARISON

# %%
# ------------------------------------------------------------
# EXAMPLE USAGE — SUPPORT TICKET SUMMARIZATION
# ------------------------------------------------------------

raw_prompt_ticket = """
Summarize this customer issue:
User says app isn’t loading, tried reinstalling, still breaks on login.
"""

tuned_prompt_ticket = """
You are a support assistant. Convert the strutured issue to structured summaries. Custoemr issue: User says app isn’t loading, tried reinstalling, still breaks on login.

Rules:
• Identify main issue.
• Extract troubleshooting attempts.
• Capture impact.
• Provide agent next steps.
• Produce a short customer-facing message.

Output:
Issue Summary:
Attempts Already Made:
Impact:
Recommended Agent Actions:
Customer-Facing Message:
"""

compare_prompts(raw_prompt_ticket, tuned_prompt_ticket, title="Support Ticket Summarization")
# Out:
# Support Ticket Summarization
# ==============================
#
# RAW PROMPT:
# --------------------------------
#
# Summarize this customer issue:
# User says app isn’t loading, tried reinstalling, still breaks on login.
#
#
# RAW RESPONSE:
#     The user is experiencing an issue where the app fails to load. They have attempted to resolve the problem by reinstalling the app, but it still crashes during the login process.
#
#
# TUNED PROMPT:
# --------------------------------
#
# You are a support assistant. Convert the strutured issue to structured summaries. Custoemr issue: User says app isn’t loading, tried reinstalling, still breaks on login.
#
# Rules:
# • Identify main issue.
# • Extract troubleshooting attempts.
# • Capture impact.
# • Provide agent next steps.
# • Produce a short customer-facing message.
#
# Output:
# Issue Summary:
# Attempts Already Made:
# Impact:
# Recommended Agent Actions:
# Customer-Facing Message:
#
#
# TUNED RESPONSE:
#     Issue Summary: The app is not loading and crashes during the login process.
#
#     Attempts Already Made: The user has tried reinstalling the app.
#
#     Impact: The user is unable to access the app, which may affect their ability to use its features and services.
#
#     Recommended Agent Actions:
#     1. Verify the user's device specifications and compatibility with the app.
#     2. Check for any known issues or outages related to the app.
#     3. Gather additional details from the user, such as error messages or logs, if available.
#     4. Suggest clearing the app cache or checking for updates to the operating system.
#
#     Customer-Facing Message: "Thank you for reaching out. I understand that you're having trouble with the app not loading and crashing on login, even after reinstalling. I'm here to help! Let me gather some more information to assist you better."
#
# ==============================
# END OF COMPARISON
