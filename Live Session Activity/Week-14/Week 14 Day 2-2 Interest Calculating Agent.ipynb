# %% [markdown]
# Practice Exercise - 2
# ====================================
# Build an Agent using Langchain tool calling agent.
#
# 1st tool -> input: principal, interest rate and period output: simple interest.
#
# 2nd tool -> input: principal, interest rate and period output: compound interest
#
# SI = P*R*T/100
# CI = P(1+R/100)^period- P
